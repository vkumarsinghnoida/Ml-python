# %% [markdown]
# <a href="https://colab.research.google.com/github/vkumarsinghnoida/Ml-python/blob/main/cs50/Week0/week0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset from the CSV file
data = pd.read_csv('house_prices.csv')

# Extract the size and price columns
size = data['Size (sq. ft.)']
price = data['Price (USD)']

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(size, price, marker='o', color='blue', alpha=0.7)
plt.title('House Prices vs. Size')
plt.xlabel('Size (sq. ft.)')
plt.ylabel('Price (USD)')
plt.grid(True)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the dataset saved in a CSV file named 'house_prices.csv'
# Adjust the file path if necessary.
file_path = 'hprices.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Extract the independent variables and the dependent variable
house_size = df['HouseSize']
num_rooms = df['NumRooms']
prices = df['Price']

# Create a scatter plot
plt.figure(figsize=(12, 6))

plt.subplot(131)
plt.scatter(house_size, prices, alpha=0.5)
plt.xlabel('House Size (sqft)')
plt.ylabel('Price')
plt.title('House Size vs. Price')

plt.subplot(132)
plt.scatter(num_rooms, prices, alpha=0.5)
plt.xlabel('Number of Rooms')
plt.ylabel('Price')
plt.title('Number of Rooms vs. Price')

plt.subplot(133)
plt.scatter(df['Location'], prices, alpha=0.5)
plt.xlabel('Location')
plt.ylabel('Price')
plt.title('Location vs. Price')

plt.tight_layout()
plt.show()
